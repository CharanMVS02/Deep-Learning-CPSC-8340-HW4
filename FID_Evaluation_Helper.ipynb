# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
if os.path.exists('Desktop/Desktop/Results/FID_score/DC_FID.npy'):
    DCGAN = np.load('Desktop/Desktop/Results/FID_score/DC_FID.npy')
else:
    print("File not found!")
# Out:
# File not found!

# %%
DCGAN = np.load('Desktop/Results/FID_score/DC_FID.npy')
WGANGP = np.load('Desktop/Results/FID_score/WGANGP_FID.npy')
ACGAN = np.load('Desktop/Results/FID_score/ACGAN_FID.npy')

# %%
plt.figure(figsize=(10,5))
plt.title("FID Scores comparsions for DCGAN vs WGAN vs ACGAN")
plt.plot(DCGAN,label="DCGAN",color='red')
plt.plot(WGANGP,label="WGAN",color='green')
plt.plot(ACGAN,label="ACGAN")
plt.xlabel("Epochs")
plt.ylabel("FID")
plt.legend()
plt.savefig('Desktop/Results/FID_summary.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
plt.show()
